# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
a = pd.read_csv("treadmill-data/combined.csv")

# %%
pd.read_csv("treadmill-data/test_measure.csv")
# Out:
#         time  Speed     HR     VO2    VCO2  RR    VE ID_test   ID
# 0          0    5.0   63.0   478.0   360.0  27  13.3     2_1    2
# 1          2    5.0   75.0   401.0   295.0  23  10.3     2_1    2
# 2          4    5.0   82.0   449.0   319.0  29  12.2     2_1    2
# 3          7    5.0   87.0   461.0   340.0  28  12.8     2_1    2
# 4          9    5.0   92.0   574.0   417.0  28  14.6     2_1    2
# ...      ...    ...    ...     ...     ...  ..   ...     ...  ...
# 575082   926    5.0  148.0  1350.0  1699.0  35  65.7   857_1  857
# 575083   927    5.0  147.0  1275.0  1605.0  32  60.1   857_1  857
# 575084   929    5.0  147.0  1259.0  1566.0  29  57.0   857_1  857
# 575085   931    5.0  147.0  1278.0  1587.0  31  58.5   857_1  857
# 575086   933    5.0  147.0  1299.0  1600.0  31  58.7   857_1  857
#
# [575087 rows x 9 columns]

# %%
pd.read_csv("treadmill-data/subject-info.csv")
# Out:
#       Age  Weight  Height  Humidity  Temperature  Sex   ID ID_test
# 0    10.8    48.8   163.0      39.0         20.7    1  543   543_1
# 1    11.8    41.0   150.0      41.0         22.3    1   11    11_1
# 2    12.2    46.0   160.0      37.0         21.5    0  829   829_1
# 3    13.2    71.0   190.0      49.0         23.8    1  284   284_1
# 4    13.7    53.8   169.7      40.0         25.3    0  341   341_1
# ..    ...     ...     ...       ...          ...  ...  ...     ...
# 987  59.1    64.7   172.0      38.0         24.4    0  856   856_2
# 988  59.7    65.2   172.0      51.0         16.8    0  856   856_3
# 989  61.3   102.0   185.0      56.0         20.5    0  390   390_1
# 990  61.6    74.0   169.0      46.0         23.9    0  596   596_1
# 991  63.0    83.5   171.5      48.0         22.2    0  296   296_1
#
# [992 rows x 8 columns]

# %%
a["age_grp"].value_counts()
# Out:
# age_grp
# (20, 30]    215502
# (30, 40]    141508
# (10, 20]    132677
# (40, 50]     71990
# (50, 60]     12124
# (60, 70]      1286
# Name: count, dtype: int64

# %%
data
# Out:
# array([[0.66541941, 0.77642763, 0.02861943, 0.49426016, 0.2629818 ,
#         0.88723855, 0.52436574, 0.99450245, 0.52109375, 0.85589795,
#         0.58294479, 0.43567277],
#        [0.49311194, 0.91605209, 0.09059716, 0.29741548, 0.76580987,
#         0.955648  , 0.78996859, 0.10470538, 0.32153283, 0.03364513,
#         0.3275837 , 0.38810136],
#        [0.03256082, 0.03023525, 0.91113979, 0.49998073, 0.26166828,
#         0.9754499 , 0.26087249, 0.14767838, 0.05907462, 0.13496493,
#         0.6266219 , 0.87982432],
#        [0.24699029, 0.2481227 , 0.60040479, 0.1243278 , 0.47575297,
#         0.54650649, 0.67018313, 0.33111725, 0.64511741, 0.4920404 ,
#         0.91330407, 0.77125282],
#        [0.63370063, 0.00128929, 0.85759397, 0.75670862, 0.76918936,
#         0.82824872, 0.32715235, 0.52253668, 0.21409962, 0.00909915,
#         0.00415546, 0.07188225],
#        [0.22812303, 0.81024059, 0.27548796, 0.09990942, 0.31521747,
# ...

# %%
data = np.random.rand(10, 12) # Example: 10x12 grid of random data
fig, ax = plt.subplots() # Create a figure and an axes object
img = ax.imshow(data, cmap="viridis") # 'cmap' specifies the color map

# %%
plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = np.linspace(0, 8, 16)
y1 = 3 + 4*x/8 + np.random.uniform(0.0, 0.5, len(x))
y2 = 1 + 2*x/8 + np.random.uniform(0.0, 0.5, len(x))

# plot
fig, ax = plt.subplots()

ax.fill_between(x, y1, y2, alpha=.5, linewidth=0)
ax.plot(x, (y1 + y2)/2, linewidth=2)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
means = a[(a["ID_test"]==1) & (a["Speed"]==5.0)].groupby("Weight")["VO2"].mean()
maxes = a[(a["ID_test"]==1) & (a["Speed"]==5.0)].groupby("Weight")["VO2"].max()
mins = a[(a["ID_test"]==1) & (a["Speed"]==5.0)].groupby("Weight")["VO2"].min()

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.fill_between(means.index, mins, maxes, alpha=.5, linewidth=0)
ax.plot(means.index, means, linewidth=2)
ax
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 fig, ax = plt.subplots(figsize=(10, 5), subplot_titles="FJLDSJKFLSDJLKFSD")
#       3 ax.fill_between(means.index, mins, maxes, alpha=.5, linewidth=0)
#       4 ax.plot(means.index, means, linewidth=2)
#
# File c:\Users\miche\miniforge3\envs\dsc80\Lib\site-packages\matplotlib\pyplot.py:1759, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1604 def subplots(
#    1605     nrows: int = 1, ncols: int = 1, *,
#    1606     sharex: bool | Literal["none", "all", "row", "col"] = False,
#    (...)
#    1613     **fig_kw
#    1614 ) -> tuple[Figure, Any]:
#    1615     """
#    1616     Create a figure and a set of subplots.
#    1617
#    (...)
#    1757
#    1758     """
# -> 1759     fig = figure(**fig_kw)
# ...
